# %% [markdown]
# # Train a Machine Learning Model
# Determine the optimal machine learning algorithm and train it.

# %%
# %matplotlib inline
import sys
from glob import glob
sys.path = glob('/projects/CSC249ADCD01/packages/*') + sys.path
from copy import deepcopy
from glob import glob
from matminer.featurizers.function import FunctionFeaturizer
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
from scipy import stats
from sklearn.dummy import DummyRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import cross_validate, cross_val_predict, RepeatedKFold, GridSearchCV
from sklearn.linear_model import BayesianRidge, LinearRegression, Lasso, LassoLars
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from stopping_power_ml.io import load_qbox_data
import pandas as pd
import numpy as np
import pickle as pkl
import os

# %%
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# Load Parsl

# %%
import parsl
from parsl import *
#from parsl_config import config
workers = IPyParallelExecutor()
dfk = DataFlowKernel(executors=[workers])
print("Parsl version : ", parsl.__version__)
# Out:
# INFO:parsl.dataflow.memoization:App caching initialized
# Parsl version :  0.4.1

# %% [markdown]
# ## Load in the Dataset
# This was created by a different notebook

# %%
data = pd.read_pickle(os.path.join('data', 'random_data.pkl.gz'))
print('Data set size:', len(data))
# Out:
# Data set size: 9800

# %% [markdown]
# Remove the initial transient

# %%
data.query('initial == False', inplace=True)
print('Training set size:', len(data))
# Out:
# Training set size: 9379

# %% [markdown]
# Determine which columns are inputs

# %%
featurizers = pkl.load(open(os.path.join('..', 'featurizers.pkl'), 'rb'))[:-1]

# %%
X_cols = sum([x.feature_labels() for x in featurizers], [])

# %%
y_col = 'force'

# %% [markdown]
# ## Test out Some ML Models
# Trying out various differentiable ML algorithms:
#
# - `DummyRegressor`: A model that returns the mean of the training set for all predictions
# - `BayesianRidge`: Ridge regression that sets the hyperparameters using Bayesian statistics
# - `Lasso`: Sparse linear model, fast to train
# - `LinearRegression`: Just Ordinary Least Squares
#
# Also throw in some feature expansion and feature selection

# %% [markdown]
# ### Create Testing Routine
# What we want to know whether a model trained on the beginning of a simulation can successfully predict forces at the end of the simulation.

# %%
@App('python', dfk)
def test_on_first_part(model, data, max_step, X_cols=X_cols, y_col=y_col):
    """Train a model only using the first part of a dataset, test it
    
    :param model: model to be tested
    :param data: dataset used for training
    :param max_step: int, maximum timestep. All data before this timestep will be used for training
    :return:
        - train_size: Number of training points
        - average_force: Average force 
        - trajectory: Force as a function of timestep"""
    import numpy as np
    # Train model on all timesteps before current
    train_data = data.query('timestep <= %d'%max_step)
    model.fit(train_data[X_cols], train_data[y_col])

    # Predict on all timesteps
    traj = model.predict(data[X_cols])

    # Store results
    return len(train_data), np.mean(traj), traj

# %%
def train_over_time(model, data, steps=None):
    """Train the model on increasingly-larger amounts of data
    
    :param model: model to be tested
    :param data: training/test data
    :param steps: increments to test at. Model is trained at all entries before this timestep
    :return: Several lists:
        - train_size: Number of training points
        - average_force: Average force (i.e., stopping power) 
        - trajectory: Full trajectory
        - step: timestep
    """
    
    # Get the default steps
    if steps is None:
        steps = np.linspace(data['timestep'].min(), data['timestep'].max(), 31, dtype=np.int)[1:]
        
    # Test the models
    futures = [test_on_first_part(deepcopy(model), data, step) for step in steps]
    train_size, mean_forces, trajs = zip(*[f.result() for f in futures])    
    return train_size, mean_forces, trajs, steps

# %%
test_results = dict()
def run_tests(model, name, verbose=False):
    """Evaluate a model, store results in test_results variable
    
    :param model: model to test
    :param name: name of results to store"""
        
    # Increase time CV
    step, mean_forces, traj, steps = train_over_time(model, data)
    
    if verbose:
        print('Model: %s - Stopping power after half simulation: predicted=%.2f actual=%.2f'%(name,
                                                                                              mean_forces[int(len(mean_forces)/2)],                                                                                 data[y_col].mean()))
        
    # Train model on whole dataset
    model.fit(data[X_cols], data[y_col])
    
    test_results[name] = {
        'over_time': {'training_size': step, 'mean_force': mean_forces, 'traj': traj, 'step':steps},
        'model': deepcopy(model.best_estimator_ if isinstance(model, GridSearchCV) else model)
    }

# %% [markdown]
# ### Run a dummy model
# Get a "non-ML" baseline

# %%
model = DummyRegressor()

# %%
# %%time
run_tests(model, 'dummy', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 0 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 0 launched on site 0
# INFO:parsl.dataflow.dflow:Task 1 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 1 launched on site 0
# INFO:parsl.dataflow.dflow:Task 2 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 2 launched on site 0
# INFO:parsl.dataflow.dflow:Task 3 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 3 launched on site 0
# INFO:parsl.dataflow.dflow:Task 4 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 0 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 4 launched on site 0
# INFO:parsl.dataflow.dflow:Task 5 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 1 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 5 launched on site 0
# INFO:parsl.dataflow.dflow:Task 2 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 6 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 3 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 6 launched on site 0
# INFO:parsl.dataflow.dflow:Task 7 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 4 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 5 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 7 launched on site 0
# INFO:parsl.dataflow.dflow:Task 8 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 8 launched on site 0
# INFO:parsl.dataflow.dflow:Task 6 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 9 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 7 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 9 launched on site 0
# INFO:parsl.dataflow.dflow:Task 10 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 8 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 9 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 10 launched on site 0
# INFO:parsl.dataflow.dflow:Task 11 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 11 launched on site 0
# INFO:parsl.dataflow.dflow:Task 12 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 10 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 12 launched on site 0
# INFO:parsl.dataflow.dflow:Task 13 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 13 launched on site 0
# INFO:parsl.dataflow.dflow:Task 11 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 14 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 12 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 14 launched on site 0
# INFO:parsl.dataflow.dflow:Task 15 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 15 launched on site 0
# INFO:parsl.dataflow.dflow:Task 13 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 16 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 14 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 16 launched on site 0
# INFO:parsl.dataflow.dflow:Task 17 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 15 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 17 launched on site 0
# INFO:parsl.dataflow.dflow:Task 18 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 16 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 18 launched on site 0
# INFO:parsl.dataflow.dflow:Task 19 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 17 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 19 launched on site 0
# INFO:parsl.dataflow.dflow:Task 20 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 18 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 20 launched on site 0
# INFO:parsl.dataflow.dflow:Task 21 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 19 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 21 launched on site 0
# INFO:parsl.dataflow.dflow:Task 22 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 20 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 22 launched on site 0
# INFO:parsl.dataflow.dflow:Task 23 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 21 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 23 launched on site 0
# INFO:parsl.dataflow.dflow:Task 24 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 22 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 24 launched on site 0
# INFO:parsl.dataflow.dflow:Task 25 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 23 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 25 launched on site 0
# INFO:parsl.dataflow.dflow:Task 26 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 26 launched on site 0
# INFO:parsl.dataflow.dflow:Task 24 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 27 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 27 launched on site 0
# INFO:parsl.dataflow.dflow:Task 25 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 28 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 28 launched on site 0
# INFO:parsl.dataflow.dflow:Task 26 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 29 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 27 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 29 launched on site 0
# INFO:parsl.dataflow.dflow:Task 28 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 29 completed with <AsyncResult: test_on_first_part:finished>
# Model: dummy - Stopping power after half simulation: predicted=0.24 actual=0.24
# Wall time: 3.75 s

# %% [markdown]
# ### Test Bayesian Ridge

# %%
model = BayesianRidge()

# %%
# %%time
run_tests(model, 'bayes', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 30 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 30 launched on site 0
# INFO:parsl.dataflow.dflow:Task 31 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 31 launched on site 0
# INFO:parsl.dataflow.dflow:Task 32 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 32 launched on site 0
# INFO:parsl.dataflow.dflow:Task 33 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 30 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 33 launched on site 0
# INFO:parsl.dataflow.dflow:Task 34 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 34 launched on site 0
# INFO:parsl.dataflow.dflow:Task 35 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 31 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 32 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 35 launched on site 0
# INFO:parsl.dataflow.dflow:Task 36 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 33 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 36 launched on site 0
# INFO:parsl.dataflow.dflow:Task 37 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 37 launched on site 0
# INFO:parsl.dataflow.dflow:Task 34 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 38 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 38 launched on site 0
# INFO:parsl.dataflow.dflow:Task 35 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 39 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 36 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 39 launched on site 0
# INFO:parsl.dataflow.dflow:Task 40 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 37 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 38 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 40 launched on site 0
# INFO:parsl.dataflow.dflow:Task 41 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 41 launched on site 0
# INFO:parsl.dataflow.dflow:Task 42 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 42 launched on site 0
# INFO:parsl.dataflow.dflow:Task 43 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 39 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 43 launched on site 0
# INFO:parsl.dataflow.dflow:Task 44 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 40 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 44 launched on site 0
# INFO:parsl.dataflow.dflow:Task 45 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 41 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 45 launched on site 0
# INFO:parsl.dataflow.dflow:Task 46 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 42 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 43 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 46 launched on site 0
# INFO:parsl.dataflow.dflow:Task 47 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 44 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 47 launched on site 0
# INFO:parsl.dataflow.dflow:Task 48 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 45 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 46 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 48 launched on site 0
# INFO:parsl.dataflow.dflow:Task 49 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 47 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 49 launched on site 0
# INFO:parsl.dataflow.dflow:Task 50 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 50 launched on site 0
# INFO:parsl.dataflow.dflow:Task 48 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 51 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 51 launched on site 0
# INFO:parsl.dataflow.dflow:Task 49 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 52 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 52 launched on site 0
# INFO:parsl.dataflow.dflow:Task 50 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 53 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 53 launched on site 0
# INFO:parsl.dataflow.dflow:Task 51 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 54 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 52 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 54 launched on site 0
# INFO:parsl.dataflow.dflow:Task 55 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 55 launched on site 0
# INFO:parsl.dataflow.dflow:Task 53 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 56 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 56 launched on site 0
# INFO:parsl.dataflow.dflow:Task 54 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 57 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 57 launched on site 0
# INFO:parsl.dataflow.dflow:Task 55 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 58 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 56 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 58 launched on site 0
# INFO:parsl.dataflow.dflow:Task 59 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 57 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 59 launched on site 0
# INFO:parsl.dataflow.dflow:Task 58 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 59 completed with <AsyncResult: test_on_first_part:finished>
# Model: bayes - Stopping power after half simulation: predicted=0.24 actual=0.24
# Wall time: 4.01 s

# %% [markdown]
# ### Test Bayesian Ridge w/ Poly Features

# %%
model = Pipeline([
    ('poly', PolynomialFeatures(degree=2, include_bias=False)),
    ('model', BayesianRidge())
])

# %%
# %%time
run_tests(model, 'bayes_poly', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 60 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 60 launched on site 0
# INFO:parsl.dataflow.dflow:Task 61 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 61 launched on site 0
# INFO:parsl.dataflow.dflow:Task 62 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 62 launched on site 0
# INFO:parsl.dataflow.dflow:Task 63 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 63 launched on site 0
# INFO:parsl.dataflow.dflow:Task 64 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 60 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 64 launched on site 0
# INFO:parsl.dataflow.dflow:Task 65 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 65 launched on site 0
# INFO:parsl.dataflow.dflow:Task 66 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 66 launched on site 0
# INFO:parsl.dataflow.dflow:Task 67 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 67 launched on site 0
# INFO:parsl.dataflow.dflow:Task 68 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 68 launched on site 0
# INFO:parsl.dataflow.dflow:Task 69 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 69 launched on site 0
# INFO:parsl.dataflow.dflow:Task 70 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 70 launched on site 0
# INFO:parsl.dataflow.dflow:Task 71 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 71 launched on site 0
# INFO:parsl.dataflow.dflow:Task 72 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 72 launched on site 0
# INFO:parsl.dataflow.dflow:Task 73 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 73 launched on site 0
# INFO:parsl.dataflow.dflow:Task 74 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 74 launched on site 0
# INFO:parsl.dataflow.dflow:Task 75 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 61 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 75 launched on site 0
# INFO:parsl.dataflow.dflow:Task 76 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 76 launched on site 0
# INFO:parsl.dataflow.dflow:Task 77 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 77 launched on site 0
# INFO:parsl.dataflow.dflow:Task 78 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 78 launched on site 0
# INFO:parsl.dataflow.dflow:Task 79 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 79 launched on site 0
# INFO:parsl.dataflow.dflow:Task 80 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 80 launched on site 0
# INFO:parsl.dataflow.dflow:Task 81 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 81 launched on site 0
# INFO:parsl.dataflow.dflow:Task 82 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 82 launched on site 0
# INFO:parsl.dataflow.dflow:Task 83 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 83 launched on site 0
# INFO:parsl.dataflow.dflow:Task 84 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 84 launched on site 0
# INFO:parsl.dataflow.dflow:Task 85 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 85 launched on site 0
# INFO:parsl.dataflow.dflow:Task 86 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 86 launched on site 0
# INFO:parsl.dataflow.dflow:Task 87 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 62 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 87 launched on site 0
# INFO:parsl.dataflow.dflow:Task 88 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 88 launched on site 0
# INFO:parsl.dataflow.dflow:Task 89 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 89 launched on site 0
# INFO:parsl.dataflow.dflow:Task 63 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 64 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 65 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 66 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 67 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 68 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 69 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 70 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 71 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 72 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 73 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 74 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 75 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 76 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 77 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 78 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 79 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 80 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 81 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 82 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 83 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 84 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 85 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 86 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 87 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 88 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 89 completed with <AsyncResult: test_on_first_part:finished>
# Model: bayes_poly - Stopping power after half simulation: predicted=0.23 actual=0.24
# Wall time: 37.1 s

# %% [markdown]
# ### Lasso

# %%
model = GridSearchCV(Lasso(normalize=True, max_iter=500), {'alpha':np.logspace(-7,-1,20)}, cv=4)

# %%
# %%time
run_tests(model, 'lasso', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 90 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 90 launched on site 0
# INFO:parsl.dataflow.dflow:Task 91 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 91 launched on site 0
# INFO:parsl.dataflow.dflow:Task 92 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 92 launched on site 0
# INFO:parsl.dataflow.dflow:Task 93 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 93 launched on site 0
# INFO:parsl.dataflow.dflow:Task 94 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 94 launched on site 0
# INFO:parsl.dataflow.dflow:Task 95 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 95 launched on site 0
# INFO:parsl.dataflow.dflow:Task 96 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 96 launched on site 0
# INFO:parsl.dataflow.dflow:Task 97 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 90 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 97 launched on site 0
# INFO:parsl.dataflow.dflow:Task 98 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 98 launched on site 0
# INFO:parsl.dataflow.dflow:Task 99 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 99 launched on site 0
# INFO:parsl.dataflow.dflow:Task 100 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 100 launched on site 0
# INFO:parsl.dataflow.dflow:Task 101 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 101 launched on site 0
# INFO:parsl.dataflow.dflow:Task 102 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 102 launched on site 0
# INFO:parsl.dataflow.dflow:Task 103 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 103 launched on site 0
# INFO:parsl.dataflow.dflow:Task 104 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 104 launched on site 0
# INFO:parsl.dataflow.dflow:Task 105 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 105 launched on site 0
# INFO:parsl.dataflow.dflow:Task 91 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 106 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 106 launched on site 0
# INFO:parsl.dataflow.dflow:Task 107 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 107 launched on site 0
# INFO:parsl.dataflow.dflow:Task 108 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 108 launched on site 0
# INFO:parsl.dataflow.dflow:Task 109 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 109 launched on site 0
# INFO:parsl.dataflow.dflow:Task 110 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 110 launched on site 0
# INFO:parsl.dataflow.dflow:Task 111 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 111 launched on site 0
# INFO:parsl.dataflow.dflow:Task 112 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 112 launched on site 0
# INFO:parsl.dataflow.dflow:Task 113 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 113 launched on site 0
# INFO:parsl.dataflow.dflow:Task 114 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 114 launched on site 0
# INFO:parsl.dataflow.dflow:Task 115 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 115 launched on site 0
# INFO:parsl.dataflow.dflow:Task 116 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 116 launched on site 0
# INFO:parsl.dataflow.dflow:Task 117 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 92 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 117 launched on site 0
# INFO:parsl.dataflow.dflow:Task 118 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 118 launched on site 0
# INFO:parsl.dataflow.dflow:Task 119 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 119 launched on site 0
# INFO:parsl.dataflow.dflow:Task 93 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 94 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 95 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 96 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 97 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 98 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 99 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 100 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 101 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 102 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 103 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 104 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 105 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 106 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 107 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 108 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 109 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 110 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 111 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 112 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 113 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 114 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 115 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 116 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 117 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 118 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 119 completed with <AsyncResult: test_on_first_part:finished>
# Model: lasso - Stopping power after half simulation: predicted=0.24 actual=0.24
# Wall time: 1min 45s

# %% [markdown]
# ### Lasso+BayesianRidge

# %%
model = GridSearchCV(Pipeline([
    ('lasso_rfe', SelectFromModel(
        LassoLars(normalize=True, max_iter=22, fit_intercept=False, alpha=1e-10))
    ),
    ('model', BayesianRidge())
]), {'lasso_rfe__estimator__max_iter':range(5,30)}, cv=4)

# %%
# %%time
run_tests(model, 'lasso+bayes', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 120 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 120 launched on site 0
# INFO:parsl.dataflow.dflow:Task 121 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 121 launched on site 0
# INFO:parsl.dataflow.dflow:Task 122 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 122 launched on site 0
# INFO:parsl.dataflow.dflow:Task 123 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 123 launched on site 0
# INFO:parsl.dataflow.dflow:Task 124 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 124 launched on site 0
# INFO:parsl.dataflow.dflow:Task 125 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 125 launched on site 0
# INFO:parsl.dataflow.dflow:Task 126 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 126 launched on site 0
# INFO:parsl.dataflow.dflow:Task 127 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 127 launched on site 0
# INFO:parsl.dataflow.dflow:Task 128 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 128 launched on site 0
# INFO:parsl.dataflow.dflow:Task 129 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 129 launched on site 0
# INFO:parsl.dataflow.dflow:Task 130 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 130 launched on site 0
# INFO:parsl.dataflow.dflow:Task 131 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 131 launched on site 0
# INFO:parsl.dataflow.dflow:Task 132 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 132 launched on site 0
# INFO:parsl.dataflow.dflow:Task 133 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 133 launched on site 0
# INFO:parsl.dataflow.dflow:Task 134 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 120 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 134 launched on site 0
# INFO:parsl.dataflow.dflow:Task 135 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 135 launched on site 0
# INFO:parsl.dataflow.dflow:Task 136 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 136 launched on site 0
# INFO:parsl.dataflow.dflow:Task 137 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 137 launched on site 0
# INFO:parsl.dataflow.dflow:Task 138 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 138 launched on site 0
# INFO:parsl.dataflow.dflow:Task 139 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 139 launched on site 0
# INFO:parsl.dataflow.dflow:Task 140 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 140 launched on site 0
# INFO:parsl.dataflow.dflow:Task 141 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 141 launched on site 0
# INFO:parsl.dataflow.dflow:Task 142 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 142 launched on site 0
# INFO:parsl.dataflow.dflow:Task 143 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 143 launched on site 0
# INFO:parsl.dataflow.dflow:Task 144 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 144 launched on site 0
# INFO:parsl.dataflow.dflow:Task 145 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 145 launched on site 0
# INFO:parsl.dataflow.dflow:Task 146 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 146 launched on site 0
# INFO:parsl.dataflow.dflow:Task 147 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 147 launched on site 0
# INFO:parsl.dataflow.dflow:Task 148 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 148 launched on site 0
# INFO:parsl.dataflow.dflow:Task 149 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 121 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 149 launched on site 0
# INFO:parsl.dataflow.dflow:Task 122 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 123 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 124 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 125 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 126 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 127 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 128 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 129 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 130 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 131 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 132 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 133 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 134 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 135 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 136 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 137 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 138 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 139 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 140 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 141 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 142 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 143 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 144 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 145 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 146 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 147 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 148 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 149 completed with <AsyncResult: test_on_first_part:finished>
# Model: lasso+bayes - Stopping power after half simulation: predicted=0.24 actual=0.24
# Wall time: 38.5 s

# %% [markdown]
# ### Test Bayesian Ridge w/ Poly Features

# %%
model = GridSearchCV(Pipeline([
    ('poly', PolynomialFeatures(degree=2, include_bias=False)),
    ('lasso_rfe', SelectFromModel(
        LassoLars(normalize=True, max_iter=35, alpha=1e-10))
    ),
    ('model', BayesianRidge())
]), {'lasso_rfe__estimator__max_iter':range(5,30)}, cv=4)

# %%
# %%time
run_tests(model, 'lasso+bayes_poly', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 150 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 150 launched on site 0
# INFO:parsl.dataflow.dflow:Task 151 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 151 launched on site 0
# INFO:parsl.dataflow.dflow:Task 152 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 152 launched on site 0
# INFO:parsl.dataflow.dflow:Task 153 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 153 launched on site 0
# INFO:parsl.dataflow.dflow:Task 154 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 154 launched on site 0
# INFO:parsl.dataflow.dflow:Task 155 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 155 launched on site 0
# INFO:parsl.dataflow.dflow:Task 156 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 156 launched on site 0
# INFO:parsl.dataflow.dflow:Task 157 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 157 launched on site 0
# INFO:parsl.dataflow.dflow:Task 158 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 158 launched on site 0
# INFO:parsl.dataflow.dflow:Task 159 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 159 launched on site 0
# INFO:parsl.dataflow.dflow:Task 160 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 160 launched on site 0
# INFO:parsl.dataflow.dflow:Task 161 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 161 launched on site 0
# INFO:parsl.dataflow.dflow:Task 162 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 162 launched on site 0
# INFO:parsl.dataflow.dflow:Task 163 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 163 launched on site 0
# INFO:parsl.dataflow.dflow:Task 164 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 164 launched on site 0
# INFO:parsl.dataflow.dflow:Task 165 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 165 launched on site 0
# INFO:parsl.dataflow.dflow:Task 166 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 166 launched on site 0
# INFO:parsl.dataflow.dflow:Task 167 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 167 launched on site 0
# INFO:parsl.dataflow.dflow:Task 168 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 168 launched on site 0
# INFO:parsl.dataflow.dflow:Task 169 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 169 launched on site 0
# INFO:parsl.dataflow.dflow:Task 170 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 170 launched on site 0
# INFO:parsl.dataflow.dflow:Task 171 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 171 launched on site 0
# INFO:parsl.dataflow.dflow:Task 172 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 172 launched on site 0
# INFO:parsl.dataflow.dflow:Task 173 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 173 launched on site 0
# INFO:parsl.dataflow.dflow:Task 174 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 174 launched on site 0
# INFO:parsl.dataflow.dflow:Task 175 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 175 launched on site 0
# INFO:parsl.dataflow.dflow:Task 176 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 176 launched on site 0
# INFO:parsl.dataflow.dflow:Task 177 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 177 launched on site 0
# INFO:parsl.dataflow.dflow:Task 178 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 178 launched on site 0
# INFO:parsl.dataflow.dflow:Task 179 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 179 launched on site 0
# INFO:parsl.dataflow.dflow:Task 150 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 151 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 152 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 153 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 154 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 155 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 156 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 157 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 158 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 159 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 160 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 161 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 162 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 163 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 164 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 165 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 166 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 167 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 168 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 169 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 170 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 171 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 172 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 173 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 174 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 175 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 176 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 177 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 178 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 179 completed with <AsyncResult: test_on_first_part:finished>
# Model: lasso+bayes_poly - Stopping power after half simulation: predicted=0.24 actual=0.24
# Wall time: 5min 12s

# %% [markdown]
# Print the chosen settings

# %%
print(test_results['lasso+bayes_poly']['model'])
# Out:
# Pipeline(memory=None,
#      steps=[('poly', PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)), ('lasso_rfe', SelectFromModel(estimator=LassoLars(alpha=1e-10, copy_X=True, eps=2.220446049250313e-16,
#      fit_intercept=True, fit_path=True, max_iter=29, normalize=True,
#      positive=False, precompute='auto...rue, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False))])

# %% [markdown]
# ### Test Ordinary Least Squares

# %%
model = LinearRegression(fit_intercept=False)

# %%
# %%time
run_tests(model, 'ols', True)
# Out:
# INFO:parsl.dataflow.dflow:Task 180 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 180 launched on site 0
# INFO:parsl.dataflow.dflow:Task 181 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 181 launched on site 0
# INFO:parsl.dataflow.dflow:Task 182 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 182 launched on site 0
# INFO:parsl.dataflow.dflow:Task 180 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 183 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 183 launched on site 0
# INFO:parsl.dataflow.dflow:Task 181 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 184 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 184 launched on site 0
# INFO:parsl.dataflow.dflow:Task 182 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 185 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 183 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 185 launched on site 0
# INFO:parsl.dataflow.dflow:Task 186 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 186 launched on site 0
# INFO:parsl.dataflow.dflow:Task 187 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 184 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 187 launched on site 0
# INFO:parsl.dataflow.dflow:Task 188 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 185 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 188 launched on site 0
# INFO:parsl.dataflow.dflow:Task 189 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 186 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 189 launched on site 0
# INFO:parsl.dataflow.dflow:Task 190 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 190 launched on site 0
# INFO:parsl.dataflow.dflow:Task 191 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 191 launched on site 0
# INFO:parsl.dataflow.dflow:Task 187 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 192 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 188 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 192 launched on site 0
# INFO:parsl.dataflow.dflow:Task 189 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 193 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 193 launched on site 0
# INFO:parsl.dataflow.dflow:Task 194 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 190 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 194 launched on site 0
# INFO:parsl.dataflow.dflow:Task 195 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 191 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 195 launched on site 0
# INFO:parsl.dataflow.dflow:Task 192 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 196 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 193 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 196 launched on site 0
# INFO:parsl.dataflow.dflow:Task 197 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 197 launched on site 0
# INFO:parsl.dataflow.dflow:Task 194 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 198 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 195 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 198 launched on site 0
# INFO:parsl.dataflow.dflow:Task 199 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 196 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 199 launched on site 0
# INFO:parsl.dataflow.dflow:Task 200 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 200 launched on site 0
# INFO:parsl.dataflow.dflow:Task 201 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 201 launched on site 0
# INFO:parsl.dataflow.dflow:Task 202 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 202 launched on site 0
# INFO:parsl.dataflow.dflow:Task 203 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 203 launched on site 0
# INFO:parsl.dataflow.dflow:Task 204 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 204 launched on site 0
# INFO:parsl.dataflow.dflow:Task 197 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 205 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 198 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 205 launched on site 0
# INFO:parsl.dataflow.dflow:Task 206 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 206 launched on site 0
# INFO:parsl.dataflow.dflow:Task 199 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 207 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 207 launched on site 0
# INFO:parsl.dataflow.dflow:Task 200 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 208 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 201 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 208 launched on site 0
# INFO:parsl.dataflow.dflow:Task 202 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 209 submitted for App test_on_first_part, waiting on tasks []
# INFO:parsl.dataflow.dflow:Task 209 launched on site 0
# INFO:parsl.dataflow.dflow:Task 203 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 204 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 205 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 206 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 207 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 208 completed with <AsyncResult: test_on_first_part:finished>
# INFO:parsl.dataflow.dflow:Task 209 completed with <AsyncResult: test_on_first_part:finished>
# Model: ols - Stopping power after half simulation: predicted=0.24 actual=0.24
# Wall time: 3.71 s

# %% [markdown]
# ## Determine the best algorithm
# As the force acting on a particle varies by several orders of magnitude and changes sign, I will use the Spearman's correlation coefficient to determine the optimal algorithm. Usually, I like to use MAE. Given the large range of forces, small variations in the very large forces have a greater impact on the MAE than relatively similar changes on the small forces. I could also use the MRE or fit to the log of the error, but the sign change makes those routes impractical. So, I choose the Spearman's correlation coefficient

# %%
num_tests = len(test_results['ols']['over_time']['traj'])

# %%
experiment_number = int(num_tests * 0.5)

train_size = test_results['lasso']['over_time']['training_size'][experiment_number]
print('Training set size: ', train_size)
results = dict([
    (name, {'force_mae': np.abs(data[y_col][train_size:] - my_data['over_time']['traj'][experiment_number][train_size:]).mean(),
            'force_spearman': stats.spearmanr(data[y_col][train_size:],
                                              my_data['over_time']['traj'][experiment_number][train_size:])[0]})
    for name, my_data in test_results.items()
])
del results['dummy']
over_time_results = pd.DataFrame(results).T
over_time_results.sort_values('force_spearman', ascending=False, inplace=True)
over_time_results
# Out:
# Training set size:  5002
#                   force_mae  force_spearman
# lasso+bayes_poly   0.019303        0.996035
# lasso              0.048652        0.993482
# ols                0.026183        0.993276
# bayes              0.027339        0.993178
# bayes_poly         0.040022        0.992343
# lasso+bayes        0.060536        0.980816

# %%
fig, ax = plt.subplots()

ax.bar(range(len(over_time_results)), over_time_results['force_spearman'])

ax.set_xticks(range(len(over_time_results)))
ax.set_xticklabels(list(over_time_results.index), fontsize=14, rotation=-45);

ax.set_ylim(0.9, 1)
ax.set_ylabel('Spearman Correlation', fontsize=18)
ax.set_xlabel('Algorithm', fontsize=18)

fig.set_size_inches(8, 5)
fig.tight_layout()

# %% [markdown]
# Select the best model

# %%
best_model = over_time_results.index[0]
print('Best model:', best_model)
# Out:
# Best model: lasso+bayes_poly

# %% [markdown]
# ## Plot just the best one
# Show the model performance

# %%
best_results = test_results['lasso+bayes_poly'] # This fits the data the best at large training set sizes

# %%
pkl.dump(best_results['model'], open('best_model.pkl', 'wb'))

# %% [markdown]
# Plot how well the algorithm forecasts stopping force

# %%
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)


for f,ax in zip([0,int(0.25*num_tests),int(0.5*num_tests),int(0.75*num_tests)],axs.flatten()):
    
    ax.plot(data['timestep'], data['force'], 'k--', lw=2)
    ax.set_ylim(ax.get_ylim()) # Make sure the scales stay appropriate
    
    traj = best_results['over_time']['traj'][f]
    ax.plot(data['timestep'], traj, 'r-', alpha=0.7, lw=2)
    traj_error = np.abs(traj - data['force']).mean()
    
    ax.text(4200, 30, 'MAE: %.3f $E_H/a_B$'%traj_error, fontsize=18,
           bbox=dict(edgecolor='k', facecolor='w'))
    
    ax.text(4000, -80, 'Training size: %d'%best_results['over_time']['training_size'][f],
            fontsize=18,
           bbox=dict(edgecolor='k', facecolor='w'))
    
    ax.plot([best_results['over_time']['step'][f],]*2, ax.get_ylim(), 'b--')
    
    ax.set_yscale('symlog')

axs[1,0].set_xlabel('Timestep', fontsize=18)
axs[1,1].set_xlabel('Timestep', fontsize=18)
axs[0,0].set_ylabel('Force ($E_H/a_B$)', fontsize=18)
axs[1,0].set_ylabel('Force ($E_H/a_B$)', fontsize=18)

fig.set_size_inches(13,6)
fig.tight_layout()

# %%
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)


for f,ax in zip([0,int(0.25*num_tests),int(0.5*num_tests),int(0.75*num_tests)],axs.flatten()):
    
    ax.plot(data['timestep'], data['force'], 'k--', lw=2)
    ax.set_ylim([0,0.4]) # Make sure the scales stay appropriate
    ax.set_xlim(4000, 5000)
    
    traj = best_results['over_time']['traj'][f]
    ax.plot(data['timestep'], traj, 'r-', alpha=0.7, lw=2)
    traj_error = np.abs(traj - data['force']).mean()
    
    ax.text(0.6, 0.9, 'MAE: %.3f $E_H/a_B$'%traj_error, fontsize=18,
           bbox=dict(edgecolor='k', facecolor='w'), transform=ax.transAxes)
    
    ax.text(0.6, 0, 'Training size: %d'%best_results['over_time']['training_size'][f],
            fontsize=18, bbox=dict(edgecolor='k', facecolor='w'), transform=ax.transAxes)
    
    ax.plot([best_results['over_time']['step'][f],]*2, ax.get_ylim(), 'b--')

axs[1,0].set_xlabel('Timestep', fontsize=18)
axs[1,1].set_xlabel('Timestep', fontsize=18)
axs[0,0].set_ylabel('Force ($E_H/a_B$)', fontsize=18)
axs[1,0].set_ylabel('Force ($E_H/a_B$)', fontsize=18)

fig.set_size_inches(13,6)
fig.tight_layout()

# %% [markdown]
# The above figure shows the fitness of the model as a function of training set size. In each frame, the model is trained on the data to the left of the blue, vertical line. The predictions of the model are shown in red and the TD-DFT result in black. After we've trained the model on half of the dataset (bottom left), the model fits the entire trajectory very well. At this point, we could stop the TD-DFT simulation and, instead, use our ML surrogate to compute the stopping power. By using the surrogate instead, we would get the same result as TD-DFT with only half of the computational expense.

# %% [markdown]
# ## Make it an animation

# %%
frames = np.linspace(1, len(data) / 2, 100, dtype=np.int)

# %%
fig, ax = plt.subplots()

ax.plot(data['timestep'], data['force'], 'k--', lw=2)

model.fit(data[X_cols].iloc[:1], data[y_col].iloc[:1])
lne, = ax.plot(data['timestep'], model.predict(data[X_cols]), 'r-', alpha=0.7, lw=2)
ax.set_ylim(ax.get_ylim())
bar, = ax.plot([data['timestep'].iloc[:1].max(),]*2, ax.get_ylim(), 'b--')

def update(frame):
    size = frames[frame]
    model.fit(data[X_cols].iloc[:size], data[y_col].iloc[:size])
    lne.set_data(data['timestep'], model.predict(data[X_cols]))
    
    bar.set_data([data['timestep'].iloc[:size].max(),]*2, ax.get_ylim())
    return lne, bar
    
anim = FuncAnimation(fig, update, frames=len(frames), interval=100, blit=True)

ax.set_yscale('symlog')
ax.set_xlabel('Timestep', fontsize=18)
ax.set_ylabel('Force ($E_H/a_B$)', fontsize=18)
fig.tight_layout()
fig.set_size_inches(8, 4)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="576" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# This video shows the changes in the fitness of the model as we add new training data. In each frame, the model is trained using all of the data to the left of the blue bar. The black line is the TD-DFT result and the red line in the ML prediction. Notice how the model first starts to accurately predict the stopping power in low-force region and then accurately models the high force regions. After we gather about half of the training data, our model predictions no longer fluctuate with adding more data.

# %%
anim.save(os.path.join('figures', 'training-animation.mp4'), dpi=330, writer='ffmpeg')

# %%
dfk.cleanup()
# Out:
# INFO:parsl.dataflow.dflow:DFK cleanup initiated
